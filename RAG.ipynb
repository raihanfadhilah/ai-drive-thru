# %% [markdown]
# # 1. Parse Menu

# %%
import json

with open('menu.json') as f:
  data = json.load(f)
menu_data = []

for menu_category, menu_item_dict in data.items():
    for menu_item, menu_item_info in menu_item_dict.items():
        if menu_category != 'Menus' and isinstance(menu_item_info, list):
            nutritional_info = {}
            item_id = menu_item
            if menu_item_info[2].keys() == {'nutritionalInfo', 'available'}:
                nutritional_info = menu_item_info[2]['nutritionalInfo']
                nutritional_info.pop('itemId')
                available = menu_item_info[2]['available']
                
            elif menu_item_info[2].keys() == {'available'}:
                available = menu_item_info[2]['available']
                
            else:
                pass
            
            allergens = nutritional_info.get('allergens', [])
            nutritional_info.pop('allergens', None)
            result = {
                "itemId": item_id,
                "category": menu_category,
                "name": menu_item_info[0],
                "price": float(menu_item_info[1]),
                "soy" : (True if 'soy' in allergens else False),
                "lactose" : (True if ("dairy" in allergens) or ("whey" in allergens) else False),
                "gluten" : (True if 'wheat' in allergens else False),
                "nutritionalInfo": nutritional_info,
                "contents": [],
                "available": bool(available)
            }
            print(result)
            menu_data.append(result)
            
        elif menu_category == 'Menus':
            item_id = menu_item
            name = menu_item_info['name']
            price = menu_item_info['price']
            contents = menu_item_info['contents']
            
            new_contents = []
            for item in contents:
                if isinstance(item, list):
                    _item_id = item[0]
                    _qty = item[1]
                    new_contents.append({
                        "itemId": _item_id,
                        "quantity": _qty
                    })
                
                elif isinstance(item, dict):
                    new_contents.append(item)
                else:
                    continue
                
            allergens = nutritional_info.get('allergens', [])
            nutritional_info.pop('allergens', None)
            result = {
                "itemId": item_id,
                "category": menu_category,
                "name": name,
                "price": price,
                "soy" : (True if 'soy' in allergens else False),
                "lactose" : (True if ("dairy" in allergens) or ("whey" in allergens) else False),
                "gluten" : (True if 'wheat' in allergens else False),
                "nutritionalInfo": {},
                "contents": new_contents,
                "available": True
            }
            print(result)
            menu_data.append(result)
# Out:
# {'itemId': 'C1', 'category': 'Chicken', 'name': 'Original Recipe', 'price': 3.5, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 400, 'fat': 22, 'protein': 28}, 'contents': [], 'available': False}
# {'itemId': 'C2', 'category': 'Chicken', 'name': 'Popcorn Chicken', 'price': 4.0, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 350, 'fat': 20, 'protein': 25}, 'contents': [], 'available': False}
# {'itemId': 'C4', 'category': 'Chicken', 'name': 'Hot Wings', 'price': 3.0, 'soy': False, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 270, 'fat': 18, 'protein': 19}, 'contents': [], 'available': False}
# {'itemId': 'C5', 'category': 'Chicken', 'name': 'Snackbox', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'C6', 'category': 'Chicken', 'name': 'Crispy Tenders', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'C7', 'category': 'Chicken', 'name': 'Original Piece', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'C8', 'category': 'Chicken', 'name': 'Tender Chicken', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'D1', 'category': 'Drinks', 'name': 'Iced Tea', 'price': 2.8, 'soy': False, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 340, 'fat': 17, 'protein': 4}, 'contents': [], 'available': False}
# {'itemId': 'D2', 'category': 'Drinks', 'name': 'Pepsi', 'price': 2.8, 'soy': False, 'lactose': True, 'gluten': False, 'nutritionalInfo': {'kcal': 170, 'fat': 10, 'protein': 2}, 'contents': [], 'available': False}
# {'itemId': 'D3', 'category': 'Drinks', 'name': '7Up', 'price': 2.8, 'soy': False, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 340, 'fat': 17, 'protein': 4}, 'contents': [], 'available': False}
# {'itemId': 'D4', 'category': 'Drinks', 'name': 'Fanta', 'price': 2.8, 'soy': False, 'lactose': True, 'gluten': False, 'nutritionalInfo': {'kcal': 170, 'fat': 10, 'protein': 2}, 'contents': [], 'available': False}
# {'itemId': 'D5', 'category': 'Drinks', 'name': 'Sourcy', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D6', 'category': 'Drinks', 'name': 'Tropicana Apple', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D7', 'category': 'Drinks', 'name': 'Guava', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D8', 'category': 'Drinks', 'name': 'Tea', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D9', 'category': 'Drinks', 'name': 'Latte', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D10', 'category': 'Drinks', 'name': 'Espresso', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D11', 'category': 'Drinks', 'name': 'Coffee', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D12', 'category': 'Drinks', 'name': 'Sisi', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D13', 'category': 'Drinks', 'name': 'Fernandes', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'D14', 'category': 'Drinks', 'name': 'Lipton', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'B1', 'category': 'Burgers', 'name': 'Crunch Burger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B2', 'category': 'Burgers', 'name': 'Original Fillet Breaded', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B3', 'category': 'Burgers', 'name': 'Original Fillet', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'B4', 'category': 'Burgers', 'name': 'Filet Burger', 'price': 4.7, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 400, 'fat': 20, 'protein': 27}, 'contents': [], 'available': False}
# {'itemId': 'B5', 'category': 'Burgers', 'name': 'Zinger Burger', 'price': 4.5, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 451, 'fat': 25, 'protein': 28}, 'contents': [], 'available': False}
# {'itemId': 'B6', 'category': 'Burgers', 'name': 'Tower Burger', 'price': 5.2, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 500, 'fat': 30, 'protein': 30}, 'contents': [], 'available': False}
# {'itemId': 'B7', 'category': 'Burgers', 'name': 'Veggie Burger', 'price': 10.0, 'soy': True, 'lactose': True, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B8', 'category': 'Burgers', 'name': 'Fire Zinger Stacker', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B9', 'category': 'Burgers', 'name': 'Fire Zinger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 100, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B10', 'category': 'Burgers', 'name': 'Colonel Stacker', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B11', 'category': 'Burgers', 'name': 'Colonel Burger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B12', 'category': 'Burgers', 'name': 'Veggie Tender', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B13', 'category': 'Burgers', 'name': 'Filet Bites', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B14', 'category': 'Burgers', 'name': 'Original Burger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B15', 'category': 'Burgers', 'name': 'Zinger Burger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B16', 'category': 'Burgers', 'name': 'Cheeseburger', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'B17', 'category': 'Burgers', 'name': 'Zinger Filet', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'S1', 'category': 'Sauces', 'name': 'Apple Sauce', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [], 'available': False}
# {'itemId': 'SD1', 'category': 'Side dishes', 'name': 'Coleslaw', 'price': 1.7, 'soy': False, 'lactose': True, 'gluten': False, 'nutritionalInfo': {'kcal': 170, 'fat': 10, 'protein': 2}, 'contents': [], 'available': False}
# {'itemId': 'SD2', 'category': 'Side dishes', 'name': 'Fries', 'price': 2.5, 'soy': False, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 340, 'fat': 17, 'protein': 4}, 'contents': [], 'available': False}
# {'itemId': 'SD3', 'category': 'Side dishes', 'name': 'Corn', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'DE1', 'category': 'Desserts', 'name': 'Chocolate Sundae', 'price': 2.5, 'soy': True, 'lactose': True, 'gluten': False, 'nutritionalInfo': {'kcal': 220, 'fat': 9, 'protein': 3}, 'contents': [], 'available': False}
# {'itemId': 'DE2', 'category': 'Desserts', 'name': 'Apple Pie', 'price': 2.2, 'soy': True, 'lactose': False, 'gluten': True, 'nutritionalInfo': {'kcal': 250, 'fat': 12, 'protein': 2}, 'contents': [], 'available': False}
# {'itemId': 'DE3', 'category': 'Desserts', 'name': 'Ice Cream', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'V1', 'category': 'Vegetarian', 'name': 'Veggie', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'V2', 'category': 'Vegetarian', 'name': 'Veggie Tenders', 'price': 15.0, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {'kcal': 150, 'fat': 100, 'protein': 10}, 'contents': [], 'available': False}
# {'itemId': 'M1', 'category': 'Menus', 'name': 'Meal Deal for 2', 'price': 4.95, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B16', 'quantity': 2}, {'itemId': 'C4', 'quantity': 4}, {'itemId': 'SD2', 'quantity': 2}, {'from': 'Drinks', 'size': 'S,L'}], 'available': True}
# {'itemId': 'M2', 'category': 'Menus', 'name': 'Meal Deal for 1', 'price': 4.95, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B16', 'quantity': 1}, {'itemId': 'C6', 'quantity': 2}, {'itemId': 'SD2', 'quantity': 1}, {'from': 'Drinks', 'size': 'S'}], 'available': True}
# {'itemId': 'M3', 'category': 'Menus', 'name': '2 Original pieces meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C7', 'quantity': 2}, {'from': 'Drinks', 'size': 'M'}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M4', 'category': 'Menus', 'name': 'Fire Zinger Burger Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B9', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'M'}], 'available': True}
# {'itemId': 'M5', 'category': 'Menus', 'name': 'Zinger Burger Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B5', 'quantity': 1}, {'itemId': 'C4', 'quantity': 2}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M6', 'category': 'Menus', 'name': 'Colonel Stacker Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B10', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M7', 'category': 'Menus', 'name': 'Snackbox 3 Filet Bites', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B13', 'quantity': 3}, {'itemId': 'SD2', 'quantity': 1}], 'available': True}
# {'itemId': 'M8', 'category': 'Menus', 'name': 'Snackbox 3 Hot Wings', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C4', 'quantity': 3}, {'itemId': 'SD2', 'quantity': 1}], 'available': True}
# {'itemId': 'M9', 'category': 'Menus', 'name': 'Colonel Burger Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B11', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M10', 'category': 'Menus', 'name': 'Snackbox 1 Original piece', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'SD2', 'quantity': 1}, {'itemId': 'C7', 'quantity': 1}], 'available': True}
# {'itemId': 'M11', 'category': 'Menus', 'name': 'Veggie Burger Meal', 'price': 15, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B7', 'quantity': 1}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 2}], 'available': True}
# {'itemId': 'M12', 'category': 'Menus', 'name': 'Original Burger Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B14', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M13', 'category': 'Menus', 'name': '3 Original pieces Boxmeal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C7', 'quantity': 3}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M14', 'category': 'Menus', 'name': 'Variety Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C4', 'quantity': 3}, {'itemId': 'C7', 'quantity': 1}, {'itemId': 'C6', 'quantity': 2}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 2}], 'available': True}
# {'itemId': 'M15', 'category': 'Menus', 'name': '4 Veggie Tender meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C4', 'quantity': 6}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M16', 'category': 'Menus', 'name': 'Veggie Burger Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 2}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M17', 'category': 'Menus', 'name': '8 Hot Wings Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C4', 'quantity': 8}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M18', 'category': 'Menus', 'name': 'Twister meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 2}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M19', 'category': 'Menus', 'name': 'Veggie Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 5}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M20', 'category': 'Menus', 'name': '4 Veggie Tender meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 4}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M21', 'category': 'Menus', 'name': 'Boneless bucket', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 10}, {'itemId': 'B13', 'quantity': 6}, {'from': 'Side dishes', 'choose': 2}], 'available': True}
# {'itemId': 'M22', 'category': 'Menus', 'name': 'Snack box 3 Filet Bites', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B13', 'quantity': 3}, {'itemId': 'SD2', 'quantity': 1}], 'available': True}
# {'itemId': 'M23', 'category': 'Menus', 'name': 'Snackbox 1 Original piece', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C7', 'quantity': 1}, {'itemId': 'SD2', 'quantity': 1}], 'available': True}
# {'itemId': 'M24', 'category': 'Menus', 'name': 'Snackbox 2 Crispy Tenders', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'SD2', 'quantity': 1}, {'itemId': 'C6', 'quantity': 2}], 'available': True}
# {'itemId': 'M25', 'category': 'Menus', 'name': 'Twister meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 2}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M26', 'category': 'Menus', 'name': 'Zinger Burger Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B15', 'quantity': 1}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M27', 'category': 'Menus', 'name': 'Original Burger Boxmeal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B14', 'quantity': 1}, {'itemId': 'C4', 'quantity': 2}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M28', 'category': 'Menus', 'name': 'Veggie Boxmeal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B12', 'quantity': 5}, {'itemId': 'D2', 'quantity': 1}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M29', 'category': 'Menus', 'name': 'Filet Bites Boxmeal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B13', 'quantity': 9}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M30', 'category': 'Menus', 'name': 'Boneless Box Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 5}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M31', 'category': 'Menus', 'name': 'Double Crunch Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B1', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M32', 'category': 'Menus', 'name': 'Snack box 2 Veggie Tenders', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 2}, {'itemId': 'SD2', 'quantity': 1}], 'available': True}
# {'itemId': 'M33', 'category': 'Menus', 'name': 'Fire Twister meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 2}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M34', 'category': 'Menus', 'name': 'Veggie Bucket', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 10}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 2}], 'available': True}
# {'itemId': 'M35', 'category': 'Menus', 'name': 'Veggie Burger Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B7', 'quantity': 2}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M36', 'category': 'Menus', 'name': 'Veggie Twister meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C6', 'quantity': 2}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M37', 'category': 'Menus', 'name': 'Veggie Kids Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 2}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Sauces', 'choose': 1}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M38', 'category': 'Menus', 'name': 'Variety bucket', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C7', 'quantity': 4}, {'itemId': 'C4', 'quantity': 6}, {'itemId': 'C6', 'quantity': 4}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Sauces', 'choose': 1}], 'available': True}
# {'itemId': 'M39', 'category': 'Menus', 'name': 'Veggie Bucket', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 10}, {'from': 'Side dishes', 'choose': 2}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M40', 'category': 'Menus', 'name': 'Family bucket', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'C4', 'quantity': 12}, {'itemId': 'C7', 'quantity': 4}, {'itemId': 'C6', 'quantity': 6}, {'itemId': 'B13', 'quantity': 9}, {'itemId': 'SD2', 'quantity': 4}, {'from': 'Side dishes', 'choose': 4}], 'available': True}
# {'itemId': 'M41', 'category': 'Menus', 'name': 'Kids Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B13', 'quantity': 3}, {'itemId': 'C7', 'quantity': 1}, {'from': 'Burgers', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}, {'from': 'Sauces', 'choose': 1}, {'from': 'Side dishes', 'choose': 1}], 'available': True}
# {'itemId': 'M42', 'category': 'Menus', 'name': 'Veggie Kids Meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'V2', 'quantity': 2}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}
# {'itemId': 'M43', 'category': 'Menus', 'name': 'Fire Zinger Stacker meal', 'price': 30, 'soy': False, 'lactose': False, 'gluten': False, 'nutritionalInfo': {}, 'contents': [{'itemId': 'B8', 'quantity': 1}, {'from': 'Side dishes', 'choose': 1}, {'from': 'Drinks', 'size': 'L'}], 'available': True}

# %% [markdown]
# # 2. Upload to DB

# %%
import weaviate
import weaviate.classes as wvc
from weaviate.classes.config import DataType, Property, VectorDistances
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
load_dotenv()

client = weaviate.connect_to_local()
client.collections.delete("Kfc_menu")
embedding_model = SentenceTransformer("multi-qa-MiniLM-L6-cos-v1")

# %%
client.collections.delete("Kfc_menu")
if not client.collections.exists("Kfc_menu"):
    collection = client.collections.create(
            name = "Kfc_menu",
            vector_index_config=wvc.config.Configure.VectorIndex.hnsw(
                distance_metric=VectorDistances.COSINE,
                quantizer = wvc.config.Configure.VectorIndex.Quantizer.pq()
            ),
            properties = [
                Property(
                    name = "itemId",
                    data_type = DataType.TEXT,
                    index_searchable=True,
                ),
                Property(
                    name = "category",
                    data_type = DataType.TEXT,
                    index_searchable=True,
                ),
                Property(
                    name = "name",
                    data_type = DataType.TEXT,
                    index_searchable=True,
                ),
                Property(
                    name = "price",
                    data_type = DataType.NUMBER,
                ),
                Property(
                    name = "nutritionalInfo",
                    data_type = DataType.OBJECT,
                    nested_properties=[
                        Property(
                            name = "kcal",
                            data_type = DataType.NUMBER,
                        ),
                        Property(
                            name = "fat",
                            data_type = DataType.NUMBER,
                            
                        ),
                        Property(
                            name = "protein",
                            data_type = DataType.NUMBER,
                        ),
                    ],
                    # skip_vectorization=True
                ),
                Property(
                    name = "lactose",
                    data_type = DataType.BOOL,
                    # index_searchable=True
                ),
                Property(
                    name = "gluten",
                    data_type = DataType.BOOL,
                    # index_searchable=True
                ),
                Property(
                    name = "soy",
                    data_type = DataType.BOOL,
                ),
                Property(
                    name="contents",
                    data_type=DataType.OBJECT_ARRAY,
                    skip_vectorization=True,
                    nested_properties=[
                        Property(
                            name="itemId",
                            data_type=DataType.TEXT
                        ),
                        Property(
                            name="quantity",
                            data_type=DataType.NUMBER
                        ),
                        Property(
                            name="from",
                            data_type=DataType.TEXT
                        ),
                        Property(
                            name="choose",
                            data_type=DataType.NUMBER
                        ),
                        Property(
                            name="size",
                            data_type=DataType.TEXT
                        )
                    ]
                ),
                Property(
                    name = "available",
                    data_type = DataType.BOOL,
                ),
            ]
        )
    
with collection.batch.dynamic() as batch:
    for item in menu_data:
        allergens_list = []
        if item["gluten"]:
            allergens_list.append('wheat (CONTAINS GLUTEN)')
        if item["lactose"]:
            allergens_list.append('dairy (CONTAINS LACTOSE)')
        if item["soy"]:
            allergens_list.append('soy (CONTAINS SOY)')
        else:
            pass

        string_to_embed = f"allergens:{allergens_list or ''}, name:{item['name'].lower()}, category:{item['category'].lower()}"
        print(string_to_embed)
        vector = embedding_model.encode(string_to_embed)
        batch.add_object(
            properties=item,
            vector = vector
        )
# Out:
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:original recipe, category:chicken
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:popcorn chicken, category:chicken
# allergens:['wheat (CONTAINS GLUTEN)'], name:hot wings, category:chicken
# allergens:, name:snackbox, category:chicken
# allergens:, name:crispy tenders, category:chicken
# allergens:, name:original piece, category:chicken
# allergens:, name:tender chicken, category:chicken
# allergens:['wheat (CONTAINS GLUTEN)'], name:iced tea, category:drinks
# allergens:['dairy (CONTAINS LACTOSE)'], name:pepsi, category:drinks
# allergens:['wheat (CONTAINS GLUTEN)'], name:7up, category:drinks
# allergens:['dairy (CONTAINS LACTOSE)'], name:fanta, category:drinks
# allergens:, name:sourcy, category:drinks
# allergens:, name:tropicana apple, category:drinks
# allergens:, name:guava, category:drinks
# allergens:, name:tea, category:drinks
# allergens:, name:latte, category:drinks
# allergens:, name:espresso, category:drinks
# allergens:, name:coffee, category:drinks
# allergens:, name:sisi, category:drinks
# allergens:, name:fernandes, category:drinks
# allergens:, name:lipton, category:drinks
# allergens:, name:crunch burger, category:burgers
# allergens:, name:original fillet breaded, category:burgers
# allergens:, name:original fillet, category:burgers
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:filet burger, category:burgers
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:zinger burger, category:burgers
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:tower burger, category:burgers
# allergens:['dairy (CONTAINS LACTOSE)', 'soy (CONTAINS SOY)'], name:veggie burger, category:burgers
# allergens:, name:fire zinger stacker, category:burgers
# allergens:, name:fire zinger, category:burgers
# allergens:, name:colonel stacker, category:burgers
# allergens:, name:colonel burger, category:burgers
# allergens:, name:veggie tender, category:burgers
# allergens:, name:filet bites, category:burgers
# allergens:, name:original burger, category:burgers
# allergens:, name:zinger burger, category:burgers
# allergens:, name:cheeseburger, category:burgers
# allergens:, name:zinger filet, category:burgers
# allergens:, name:apple sauce, category:sauces
# allergens:['dairy (CONTAINS LACTOSE)'], name:coleslaw, category:side dishes
# allergens:['wheat (CONTAINS GLUTEN)'], name:fries, category:side dishes
# allergens:, name:corn, category:side dishes
# allergens:['dairy (CONTAINS LACTOSE)', 'soy (CONTAINS SOY)'], name:chocolate sundae, category:desserts
# allergens:['wheat (CONTAINS GLUTEN)', 'soy (CONTAINS SOY)'], name:apple pie, category:desserts
# allergens:, name:ice cream, category:desserts
# allergens:, name:veggie, category:vegetarian
# allergens:, name:veggie tenders, category:vegetarian
# allergens:, name:meal deal for 2, category:menus
# allergens:, name:meal deal for 1, category:menus
# allergens:, name:2 original pieces meal, category:menus
# allergens:, name:fire zinger burger meal, category:menus
# allergens:, name:zinger burger box meal, category:menus
# allergens:, name:colonel stacker meal, category:menus
# allergens:, name:snackbox 3 filet bites, category:menus
# allergens:, name:snackbox 3 hot wings, category:menus
# allergens:, name:colonel burger meal, category:menus
# allergens:, name:snackbox 1 original piece, category:menus
# allergens:, name:veggie burger meal, category:menus
# allergens:, name:original burger meal, category:menus
# allergens:, name:3 original pieces boxmeal, category:menus
# allergens:, name:variety box meal, category:menus
# allergens:, name:4 veggie tender meal, category:menus
# allergens:, name:veggie burger box meal, category:menus
# allergens:, name:8 hot wings box meal, category:menus
# allergens:, name:twister meal, category:menus
# allergens:, name:veggie box meal, category:menus
# allergens:, name:4 veggie tender meal, category:menus
# allergens:, name:boneless bucket, category:menus
# allergens:, name:snack box 3 filet bites, category:menus
# allergens:, name:snackbox 1 original piece, category:menus
# allergens:, name:snackbox 2 crispy tenders, category:menus
# allergens:, name:twister meal, category:menus
# allergens:, name:zinger burger meal, category:menus
# allergens:, name:original burger boxmeal, category:menus
# allergens:, name:veggie boxmeal, category:menus
# allergens:, name:filet bites boxmeal, category:menus
# allergens:, name:boneless box meal, category:menus
# allergens:, name:double crunch meal, category:menus
# allergens:, name:snack box 2 veggie tenders, category:menus
# allergens:, name:fire twister meal, category:menus
# allergens:, name:veggie bucket, category:menus
# allergens:, name:veggie burger meal, category:menus
# allergens:, name:veggie twister meal, category:menus
# allergens:, name:veggie kids meal, category:menus
# allergens:, name:variety bucket, category:menus
# allergens:, name:veggie bucket, category:menus
# allergens:, name:family bucket, category:menus
# allergens:, name:kids meal, category:menus
# allergens:, name:veggie kids meal, category:menus
# allergens:, name:fire zinger stacker meal, category:menus

# %% [markdown]
# # 3. Experiment with Retriever

# %%
import weaviate
import weaviate.classes as wvc
import time
from drive_thru_bot.agent.retriever import Retriever

client = weaviate.connect_to_local()
collection = client.collections.get("Kfc_menu")

retriever = Retriever(client=client, collection_name="kfc_menu")

# %% [markdown]
# ### Consider the following questions being asked:
#
# - Hi, do you have cola?
# - Hi I want to have a Fire Zinger Stacker without sauce and a cola
# - Give me a Veggie Tender, medium, with salad
# - Give me an orange chocolate milkshake, medium
# - Give me the gluten free burger options
# - How many calories does the Colonel have?
# - Can I get a Whopper?

# %%
test_queries = [
    "Hi, do you have cola?",
    "Hi I want to have a Fire Zinger Stacker without sauce and a cola",
    "Give me a Veggie Tender, medium, with salad",
    "Give me an orange chocolate milkshake, medium",
    "Give me gluten free burger options",
    "How many calories does the Colonel have?",
    "Can I get a Whopper?"
]

# %%
for query in test_queries:
    print('Query:', query)
    init_time = time.time()
    result = retriever.query(
        query=query,
        search_type="hybrid",
        query_properties=["name", "category^3"],
        fusion_type=wvc.query.HybridFusion.RELATIVE_SCORE,
        alpha = 0.9,
        limit = 10,
        auto_limit = 1)
    
    print('Time taken: ', (time.time() - init_time)*1000, "ms")
    print([res.properties['name'] for res in result.objects], "\n\n")
# Out:
# Query: Hi, do you have cola?
# Time taken:  18.758058547973633 ms
# ['Pepsi']
#
#
# Query: Hi I want to have a Fire Zinger Stacker without sauce and a cola
# Time taken:  14.547348022460938 ms
# ['Fire Zinger Stacker', 'Fire Zinger Stacker meal']
#
#
# Query: Give me a Veggie Tender, medium, with salad
# Time taken:  17.27581024169922 ms
# ['Veggie Tender', '4 Veggie Tender meal', '4 Veggie Tender meal', 'Veggie Tenders']
#
#
# Query: Give me an orange chocolate milkshake, medium
# Time taken:  13.79847526550293 ms
# ['Chocolate Sundae']
#
#
# Query: Give me gluten free burger options
# Time taken:  12.88461685180664 ms
# ['Tower Burger', 'Zinger Burger', 'Filet Burger']
#
#
# Query: How many calories does the Colonel have?
# Time taken:  9.139537811279297 ms
# ['Colonel Burger', 'Colonel Burger Meal', 'Colonel Stacker', 'Colonel Stacker Meal']
#
#
# Query: Can I get a Whopper?
# Time taken:  12.122154235839844 ms
# ['Colonel Burger', 'Colonel Stacker']
